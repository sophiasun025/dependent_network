# %% [markdown]
# # Dependent SBM: Residual Mean vs Median Ratio, T = 200
#
# Simulation prototype for comparing three KAP-CPD variants across rho values:
#
# - `K_resid_raw_mean`
# - `K_ratio_median`
# - original unadjusted `K`
#
# For each rho, the notebook runs 100 independent repeats. For each repeat and method it records:
#
# - `detected`: permutation p-value <= 0.05
# - `accurate_detected`: detected and `abs(tauhat - tau) <= 0.05 * T`
#
# The final summary reports the mean of those indicators across repeats.

# %%
import os
import sys
import time
import importlib
from pathlib import Path

import numpy as np
import pandas as pd
from tqdm.auto import tqdm

try:
    import google.colab  # type: ignore
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')

LOCAL_PROJECT_ROOT = Path('/Users/sophiasun/networkcp/Dependent_networks/python')
COLAB_PROJECT_ROOT = Path('/content/dependent_network/python')

if LOCAL_PROJECT_ROOT.exists():
    PROJECT_ROOT = LOCAL_PROJECT_ROOT
    RUNTIME_ENV = 'local'
elif COLAB_PROJECT_ROOT.exists():
    PROJECT_ROOT = COLAB_PROJECT_ROOT
    RUNTIME_ENV = 'colab'
else:
    raise FileNotFoundError(
        'Could not find the project root. On Colab, run:\n'
        '%cd /content\n'
        '!git clone https://github.com/sophiasun025/dependent_network.git\n'
        '%cd /content/dependent_network/python'
    )

SRC_PATH = PROJECT_ROOT / 'src'
if str(SRC_PATH) not in sys.path:
    sys.path.insert(0, str(SRC_PATH))

import dependent_networks.dependent_network_functions as dnf
importlib.reload(dnf)

print('Runtime environment:', RUNTIME_ENV)
print('Project root:', PROJECT_ROOT)
print('Using module:', dnf.__file__)

#check device
import jax
print(jax.default_backend())
print(jax.devices())
# Out:
# Mounted at /content/drive
# Runtime environment: colab
# Project root: /content/dependent_network/python
# Using module: /content/dependent_network/python/src/dependent_networks/dependent_network_functions.py
# gpu
# [CudaDevice(id=0)]

# %%
# Simulation settings
RHO_VALUES = [0.1,0.2]
SIGNAL_VALUES = [0.05, 0]
RUN_NAME = "rho01_02_lagT_30_20_12_6"
T = 200
TAU = 70
BLOCK_NUMS = [10, 10, 10, 10, 10]
N_REPEATS = 100
ALPHA = 0.05
ACCURACY_TOL = 0.05 * T

# Permutation settings. Use B_PERM=1000 for final runs.
# BATCH_SIZE keeps JAX permutation memory bounded on Colab/GPU.
B_PERM = 1000
BATCH_SIZE = 200

# Lag adjustment settings for the dependent methods.
MAX_LAGS = [T,30,20,12,6]
    
# Seeds are deterministic/reproducible and unique per signal/rho/repeat.
BASE_SEED = 20260601

DEPENDENT_METHODS = [
    {'base_method': 'K_resid_raw_mean', 'adjust_type': 'K_resid_raw_mean'},
    {'base_method': 'K_ratio_median', 'adjust_type': 'K_ratio_median'},
]

METHODS = [
    {
        'name': f"{method['base_method']}_lag{max_lag}",
        'base_method': method['base_method'],
        'adjust_type': method['adjust_type'],
        'max_lag': max_lag,
    }
    for method in DEPENDENT_METHODS
    for max_lag in MAX_LAGS
]
METHODS.append({
    'name': 'original_K',
    'base_method': 'original_K',
    'adjust_type': None,
    'max_lag': None,
})

# Local writes to the repo. Colab writes to Google Drive when mounted, so results
# survive runtime resets; otherwise it falls back to the cloned repo under /content.
if IN_COLAB and Path('/content/drive/MyDrive').exists():
    RESULTS_DIR = Path('/content/drive/MyDrive/dependent_network_results')
else:
    RESULTS_DIR = PROJECT_ROOT / 'notebooks' / 'results'
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

DETAIL_PATH = RESULTS_DIR / f'dependent_SBM_resid_medianratio_T={T}_detail_{RUN_NAME}.csv'
SUMMARY_PATH = RESULTS_DIR / f'dependent_SBM_resid_medianratio_T={T}_summary_{RUN_NAME}.csv'

print('Signals:', SIGNAL_VALUES)
print('Methods:', len(METHODS))
print('Lag grid:', MAX_LAGS)
print('Detail path:', DETAIL_PATH)
print('Summary path:', SUMMARY_PATH)
# Out:
# Signals: [0.05, 0]
# Methods: 9
# Lag grid: [200, 20, 12, 6]
# Detail path: /content/drive/MyDrive/dependent_network_results/dependent_SBM_resid_medianratio_T=200_detail_rho0_005_lagT_20_12_6.csv
# Summary path: /content/drive/MyDrive/dependent_network_results/dependent_SBM_resid_medianratio_T=200_summary_rho0_005_lagT_20_12_6.csv

# %%
def simulation_seed(signal_index: int, rho_index: int, repeat_index: int) -> int:
    return BASE_SEED + 1_000_000 * signal_index + 10_000 * rho_index + repeat_index


def simulate_once(rho: float, signal: float, seed: int):
    return dnf.generate_dependent_sbm_cp_jax(
        rho=rho,
        p_within_before=0.3,
        p_within_after=0.3 + signal,
        p_across_before=0.2,
        p_across_after=0.2,
        block_nums=BLOCK_NUMS,
        tau=TAU,
        T=T,
        seed=seed,
        include_graphlet_kernel=True,
    )


def evaluate_method(K1_raw, K2_raw, method: dict, seed: int) -> dict:
    method_name = method['name']
    base_method = method['base_method']
    adjust_type = method['adjust_type']
    max_lag = method['max_lag']

    if adjust_type is None:
        stat = dnf.kap_cpd_statistic(K1_raw, K2_raw, n=T)
        pvalue = dnf.kap_cpd_permutation_pvalue_batched(
            K1_raw,
            K2_raw,
            B=B_PERM,
            batch_size=BATCH_SIZE,
            n=T,
            seed=seed,
        )
    else:
        stat = dnf.kap_cpd_statistic_dependent(
            K1_raw,
            K2_raw,
            n=T,
            adjust_type=adjust_type,
            max_lag=max_lag,
        )
        pvalue = dnf.kap_cpd_permutation_pvalue_dependent_batched(
            K1_raw,
            K2_raw,
            adjust_type=adjust_type,
            max_lag=max_lag,
            B=B_PERM,
            batch_size=BATCH_SIZE,
            n=T,
            seed=seed,
        )

    tauhat = stat['S']['tauhat']
    detected = pvalue <= ALPHA
    accurate_detected = detected and (abs(tauhat - TAU) <= ACCURACY_TOL)

    return {
        'method': method_name,
        'base_method': base_method,
        'adjust_type': adjust_type,
        'max_lag': max_lag,
        'pvalue': float(pvalue),
        'tauhat': int(tauhat),
        'S_max': float(stat['S']['max']),
        'detected': bool(detected),
        'accurate_detected': bool(accurate_detected),
    }


def load_existing_results() -> pd.DataFrame:
    if DETAIL_PATH.exists():
        return pd.read_csv(DETAIL_PATH)
    return pd.DataFrame()


def append_rows(rows: list[dict]) -> None:
    df = pd.DataFrame(rows)
    write_header = not DETAIL_PATH.exists()
    df.to_csv(DETAIL_PATH, mode='a', header=write_header, index=False)


def summarize_results(df: pd.DataFrame) -> pd.DataFrame:
    summary = (
        df.groupby(['signal', 'rho', 'method', 'base_method', 'adjust_type', 'max_lag'], dropna=False, as_index=False)
        .agg(
            repeats=('repeat', 'nunique'),
            detection=('detected', 'mean'),
            accurate_detection=('accurate_detected', 'mean'),
            mean_pvalue=('pvalue', 'mean'),
            median_pvalue=('pvalue', 'median'),
            mean_tauhat=('tauhat', 'mean'),
            median_tauhat=('tauhat', 'median'),
        )
        .sort_values(['signal', 'rho', 'base_method', 'max_lag'], na_position='last')
    )
    return summary

# %%
# Run simulation. This cell is resume-friendly: completed signal/rho/repeat/method rows are skipped.
existing = load_existing_results()
completed = set()
if not existing.empty:
    completed = set(zip(existing['signal'], existing['rho'], existing['repeat'], existing['method']))
    print(f'Resuming from {len(existing)} existing method-level rows.')

start_time = time.time()

for signal_index, signal in enumerate(tqdm(SIGNAL_VALUES, desc='signal')):
    for rho_index, rho in enumerate(tqdm(RHO_VALUES, desc=f'rho signal={signal}', leave=False)):
        for repeat_index in tqdm(range(N_REPEATS), desc=f'repeats signal={signal}, rho={rho}', leave=False):
            pending_methods = [
                method for method in METHODS
                if (signal, rho, repeat_index, method['name']) not in completed
            ]
            if not pending_methods:
                continue

            seed = simulation_seed(signal_index, rho_index, repeat_index)
            toy_data = simulate_once(rho=rho, signal=signal, seed=seed)
            K1_raw = toy_data.K1
            K2_raw = toy_data.K2

            rows = []
            for method_index, method in enumerate(pending_methods):
                method_seed = seed + 1_000_000_000 * (method_index + 1)
                result = evaluate_method(K1_raw, K2_raw, method, seed=method_seed)
                rows.append({
                    'signal': signal,
                    'rho': rho,
                    'repeat': repeat_index,
                    'seed': seed,
                    'T': T,
                    'tau': TAU,
                    'B_perm': B_PERM,
                    'batch_size': BATCH_SIZE,
                    **result,
                })

            append_rows(rows)
            completed.update((row['signal'], row['rho'], row['repeat'], row['method']) for row in rows)

elapsed = time.time() - start_time
print(f'Done or resumed all requested rows in {elapsed / 60:.2f} minutes.')
# Out:
# signal:   0%|          | 0/2 [00:00<?, ?it/s]
# rho signal=0.05:   0%|          | 0/2 [00:00<?, ?it/s]
# repeats signal=0.05, rho=0:   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# XlaRuntimeError                           Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /usr/local/lib/python3.12/dist-packages/jax/_src/xla_bridge.py in _init_backend(platform)
#     895   logger.debug("Initializing backend '%s'", platform)
# --> 896   backend = registration.factory()
#     897   # TODO(skye): consider raising more descriptive errors directly from backend
#
# /usr/local/lib/python3.12/dist-packages/jax/_src/xla_bridge.py in make_pjrt_c_api_client(plugin_name, options)
#     548   if distributed.global_state.client is None:
# --> 549     return xla_client.make_c_api_client(plugin_name, updated_options, None)
#     550
#
# /usr/local/lib/python3.12/dist-packages/jaxlib/xla_client.py in make_c_api_client(plugin_name, options, distributed_client, transfer_server_factory)
#     155     options = {}
# --> 156   return _xla.get_c_api_client(
#     157       plugin_name,
#
# XlaRuntimeError: INTERNAL: no supported devices found for platform CUDA
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_52545/2445693422.py in <cell line: 0>()
#      19
#      20             seed = simulation_seed(signal_index, rho_index, repeat_index)
# ---> 21             toy_data = simulate_once(rho=rho, signal=signal, seed=seed)
#      22             K1_raw = toy_data.K1
#      23             K2_raw = toy_data.K2
#
# /tmp/ipykernel_52545/651569448.py in simulate_once(rho, signal, seed)
#       4
#       5 def simulate_once(rho: float, signal: float, seed: int):
# ----> 6     return dnf.generate_dependent_sbm_cp_jax(
#       7         rho=rho,
#       8         p_within_before=0.3,
#
# /content/dependent_network/python/src/dependent_networks/dependent_network_functions.py in generate_dependent_sbm_cp_jax(rho, p_within_before, p_across_before, p_within_after, p_across_after, block_nums, tau, T, seed, include_graphlet_kernel)
#     166         raise ValueError("tau should satisfy 2 <= tau < T - 2, matching the R check")
#     167
# --> 168     E_before_jax, E_after_jax, community_jax = _make_probability_matrices_jax(
#     169         p_within_before,
#     170         p_across_before,
#
# /content/dependent_network/python/src/dependent_networks/dependent_network_functions.py in _make_probability_matrices_jax(p_within_before, p_across_before, p_within_after, p_across_after, block_nums)
#     100     block_nums: Array,
#     101 ) -> tuple[jax.Array, jax.Array, jax.Array]:
# --> 102     block_nums_jax = jnp.asarray(block_nums, dtype=jnp.int32)
#     103     community = jnp.repeat(jnp.arange(1, block_nums_jax.size + 1), block_nums_jax, total_repeat_length=int(np.sum(block_nums)))
#     104     same_community = community[:, None] == community[None, :]
#
# /usr/local/lib/python3.12/dist-packages/jax/_src/numpy/array_constructors.py in asarray(a, dtype, order, copy, device)
#     382   if dtype is not None:
#     383     dtype = dtypes.check_and_canonicalize_user_dtype(dtype, "asarray")
# --> 384   return array(a, dtype=dtype, copy=bool(copy), order=order, device=device)
#
# /usr/local/lib/python3.12/dist-packages/jax/_src/numpy/array_constructors.py in array(object, dtype, copy, order, ndmin, device)
#     268   else:
#     269     raise TypeError(f"Unexpected input type for array: {type(object)}")
# --> 270   out_array: Array = lax._convert_element_type(
#     271       out, dtype, weak_type=weak_type, sharding=sharding)
#     272   if ndmin > np.ndim(out_array):
#
# /usr/local/lib/python3.12/dist-packages/jax/_src/lax/lax.py in _convert_element_type(operand, new_dtype, weak_type, sharding, warn_on_complex_to_real_cast)
#    1741     return operand
#    1742   else:
# -> 1743     return convert_element_type_p.bind(
#    1744         operand, new_dtype=new_dtype, weak_type=bool(weak_type),
#    1745         sharding=sharding)
#
# /usr/local/lib/python3.12/dist-packages/jax/_src/core.py in bind(self, *args, **params)
#     632   def bind(self, *args, **params):
#     633     args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 634     return self._true_bind(*args, **params)
#     635
#     636   def _true_bind(self, *args, **params):
#
# /usr/local/lib/python3.12/dist-packages/jax/_src/core.py in _true_bind(self, *args, **params)
#     648     trace_ctx.set_trace(eval_trace)
#     649     try:
# --> 650       return self.bind_with_trace(prev_trace, args, params)
#     651     finally:
#     652       trace_ctx.set_trace(prev_trace)
#
# /usr/local/lib/python3.12/dist-packages/jax/_src/lax/lax.py in _convert_element_type_bind_with_trace(trace, args, params)
#    4986 def _convert_element_type_bind_with_trace(trace, args, params):
#    4987   sharding = params['sharding']
# -> 4988   operand = core.Primitive.bind_with_trace(convert_element_type_p, trace, args, params)
#    4989   if sharding is not None and sharding._is_concrete:
#    4990     with core.set_current_trace(trace):
#
# /usr/local/lib/python3.12/dist-packages/jax/_src/core.py in bind_with_trace(self, trace, args, params)
#     660         with set_current_trace(trace):
#     661           return self.to_lojax(*args, **params)  # type: ignore
# --> 662       return trace.process_primitive(self, args, params)
#     663     trace.process_primitive(self, args, params)  # may raise lojax error
#     664     raise Exception(f"couldn't apply typeof to args: {args}")
#
# /usr/local/lib/python3.12/dist-packages/jax/_src/core.py in process_primitive(self, primitive, args, params)
#    1187       args = map(full_lower, args)
#    1188       check_eval_args(args)
# -> 1189       return primitive.impl(*args, **params)
#    1190
#    1191   def process_call(self, primitive, f, tracers, params):
#
# /usr/local/lib/python3.12/dist-packages/jax/_src/dispatch.py in apply_primitive(prim, *args, **params)
#      88   prev = lib.jax_jit.swap_thread_local_state_disable_jit(False)
#      89   try:
# ---> 90     outs = fun(*args)
#      91   finally:
#      92     lib.jax_jit.swap_thread_local_state_disable_jit(prev)
#
#     [... skipping hidden 13 frame]
#
# /usr/local/lib/python3.12/dist-packages/jax/_src/xla_bridge.py in backends()
#     826           else:
#     827             err_msg += " (you may need to uninstall the failing plugin package, or set JAX_PLATFORMS=cpu to skip this backend.)"
# --> 828           raise RuntimeError(err_msg)
#     829
#     830     assert _default_backend is not None
#
# RuntimeError: Unable to initialize backend 'cuda': INTERNAL: no supported devices found for platform CUDA (you may need to uninstall the failing plugin package, or set JAX_PLATFORMS=cpu to skip this backend.)

# %%
# Aggregate detection metrics across repeats.
detail = pd.read_csv(DETAIL_PATH)
summary = summarize_results(detail)
summary.to_csv(SUMMARY_PATH, index=False)
summary[['signal','rho','method','detection','accurate_detection']]
# Out:
#     signal   rho                   method  detection  accurate_detection
# 3     0.00  0.00      K_ratio_median_lag6       0.01                0.00
# 0     0.00  0.00     K_ratio_median_lag12       0.00                0.00
# 1     0.00  0.00     K_ratio_median_lag20       0.01                0.00
# 2     0.00  0.00    K_ratio_median_lag200       0.01                0.00
# 7     0.00  0.00    K_resid_raw_mean_lag6       0.07                0.00
# 4     0.00  0.00   K_resid_raw_mean_lag12       0.07                0.00
# 5     0.00  0.00   K_resid_raw_mean_lag20       0.09                0.00
# 6     0.00  0.00  K_resid_raw_mean_lag200       0.01                0.00
# 8     0.00  0.00               original_K       0.04                0.00
# 12    0.00  0.05      K_ratio_median_lag6       0.05                0.00
# 9     0.00  0.05     K_ratio_median_lag12       0.06                0.00
# 10    0.00  0.05     K_ratio_median_lag20       0.05                0.00
# 11    0.00  0.05    K_ratio_median_lag200       0.05                0.00
# 16    0.00  0.05    K_resid_raw_mean_lag6       0.09                0.00
# 13    0.00  0.05   K_resid_raw_mean_lag12       0.08                0.00
# 14    0.00  0.05   K_resid_raw_mean_lag20       0.07                0.00
# 15    0.00  0.05  K_resid_raw_mean_lag200       0.05                0.00
# 17    0.00  0.05               original_K       0.15                0.01
# 21    0.05  0.00      K_ratio_median_lag6       0.71                0.43
# 18    0.05  0.00     K_ratio_median_lag12       0.68                0.40
# 19    0.05  0.00     K_ratio_median_lag20       0.70                0.42
# 20    0.05  0.00    K_ratio_median_lag200       0.69                0.41
# 25    0.05  0.00    K_resid_raw_mean_lag6       1.00                0.70
# 22    0.05  0.00   K_resid_raw_mean_lag12       1.00                0.00
# 23    0.05  0.00   K_resid_raw_mean_lag20       1.00                0.00
# 24    0.05  0.00  K_resid_raw_mean_lag200       0.56                0.39
# 26    0.05  0.00               original_K       1.00                0.89
# 30    0.05  0.05      K_ratio_median_lag6       0.57                0.27
# 27    0.05  0.05     K_ratio_median_lag12       0.57                0.27
# 28    0.05  0.05     K_ratio_median_lag20       0.58                0.29
# 29    0.05  0.05    K_ratio_median_lag200       0.59                0.29
# 34    0.05  0.05    K_resid_raw_mean_lag6       1.00                0.50
# 31    0.05  0.05   K_resid_raw_mean_lag12       1.00                0.00
# 32    0.05  0.05   K_resid_raw_mean_lag20       1.00                0.00
# 33    0.05  0.05  K_resid_raw_mean_lag200       0.47                0.29
# 35    0.05  0.05               original_K       1.00                0.81

# %%
# Quick pivot table for the two requested metrics.
summary.pivot(index='rho', columns='method', values=['detection', 'accurate_detection'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4863/1877931043.py in <cell line: 0>()
#       1 # Quick pivot table for the two requested metrics.
# ----> 2 summary.pivot(index='rho', columns='method', values=['detection', 'accurate_detection'])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in pivot(self, columns, index, values)
#    9337         from pandas.core.reshape.pivot import pivot
#    9338
# -> 9339         return pivot(self, index=index, columns=columns, values=values)
#    9340
#    9341     _shared_docs[
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/pivot.py in pivot(data, columns, index, values)
#     568     # [List[Any], ExtensionArray, ndarray[Any, Any], Index, Series]"; expected
#     569     # "Hashable"
# --> 570     result = indexed.unstack(columns_listlike)  # type: ignore[arg-type]
#     571     result.index.names = [
#     572         name if name is not lib.no_default else None for name in result.index.names
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in unstack(self, level, fill_value, sort)
#    9926         from pandas.core.reshape.reshape import unstack
#    9927
# -> 9928         result = unstack(self, level, fill_value, sort)
#    9929
#    9930         return result.__finalize__(self, method="unstack")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/reshape.py in unstack(obj, level, fill_value, sort)
#     502     if isinstance(obj, DataFrame):
#     503         if isinstance(obj.index, MultiIndex):
# --> 504             return _unstack_frame(obj, level, fill_value=fill_value, sort=sort)
#     505         else:
#     506             return obj.T.stack(future_stack=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/reshape.py in _unstack_frame(obj, level, fill_value, sort)
#     527 ) -> DataFrame:
#     528     assert isinstance(obj.index, MultiIndex)  # checked by caller
# --> 529     unstacker = _Unstacker(
#     530         obj.index, level=level, constructor=obj._constructor, sort=sort
#     531     )
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/reshape.py in __init__(self, index, level, constructor, sort)
#     152             )
#     153
# --> 154         self._make_selectors()
#     155
#     156     @cache_readonly
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/reshape.py in _make_selectors(self)
#     208
#     209         if mask.sum() < len(self.index):
# --> 210             raise ValueError("Index contains duplicate entries, cannot reshape")
#     211
#     212         self.group_index = comp_index
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
# Sanity checks: expected rows and any missing combinations.
expected_rows = len(SIGNAL_VALUES) * len(RHO_VALUES) * N_REPEATS * len(METHODS)
actual_rows = len(pd.read_csv(DETAIL_PATH)) if DETAIL_PATH.exists() else 0
print('Expected rows:', expected_rows)
print('Actual rows:', actual_rows)

if actual_rows:
    detail = pd.read_csv(DETAIL_PATH)
    missing = []
    for signal in SIGNAL_VALUES:
        for rho in RHO_VALUES:
            for repeat_index in range(N_REPEATS):
                for method in METHODS:
                    mask = (
                        (detail['signal'] == signal)
                        & (detail['rho'] == rho)
                        & (detail['repeat'] == repeat_index)
                        & (detail['method'] == method['name'])
                    )
                    if not mask.any():
                        missing.append((signal, rho, repeat_index, method['name']))
    print('Missing combinations:', len(missing))
    if missing[:10]:
        print('First missing:', missing[:10])
